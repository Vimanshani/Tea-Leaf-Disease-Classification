# %%
"""
Tea Disease Classification
Includes: Proper fine-tuning, early stopping, weighted sampler, TTA
"""

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Data.zip" -d /content/

# ─────────────────────────────────────────────
# 1. DATASET SPLIT (stratified 70/15/15)
# ─────────────────────────────────────────────
import os
import random
import shutil
import hashlib

random.seed(42)

source_dir = "/content/Data"
target_dir = "/content/drive/MyDrive/Dataset"

train_ratio = 0.70
val_ratio   = 0.15
test_ratio  = 0.15

for split in ["train", "val", "test"]:
    for cls in os.listdir(source_dir):
        os.makedirs(os.path.join(target_dir, split, cls), exist_ok=True)

for cls in os.listdir(source_dir):
    images = os.listdir(os.path.join(source_dir, cls))
    random.shuffle(images)

    n         = len(images)
    train_end = int(n * train_ratio)
    val_end   = int(n * (train_ratio + val_ratio))

    for i, img in enumerate(images):
        src = os.path.join(source_dir, cls, img)
        if i < train_end:
            dst = os.path.join(target_dir, "train", cls, img)
        elif i < val_end:
            dst = os.path.join(target_dir, "val",   cls, img)
        else:
            dst = os.path.join(target_dir, "test",  cls, img)
        shutil.copy(src, dst)

print("Stratified split completed.\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00577.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00578.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00579.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00581.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00582.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00583.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00585.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00588.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00589.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00590.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00592.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00594.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00595.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00597.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00600.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00602.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00605.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00606.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00607.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00608.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00609.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00610.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00611.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00612.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00613.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00614.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00615.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00616.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00617.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00618.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00620.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00621.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00622.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00624.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00626.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00628.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00630.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00631.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00632.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00637.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00639.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00642.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00644.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00646.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00649.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00652.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00653.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00654.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00655.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00656.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00657.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00658.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00660.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00662.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00663.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00664.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00665.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00666.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00667.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00669.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00670.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00671.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00672.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00675.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00676.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00677.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00684.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00686.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00687.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00688.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00689.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00692.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00693.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00694.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00695.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00698.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00700.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00701.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00702.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00704.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00706.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00710.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00717.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00719.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00720.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00722.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00723.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00724.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00726.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00729.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00730.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00731.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00735.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00736.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00739.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00740.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00742.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00744.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00746.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00748.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00750.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00753.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00754.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00756.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00759.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00760.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00762.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00763.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00764.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00765.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00767.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00769.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00770.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00772.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00774.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00776.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00778.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00780.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00781.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00782.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00784.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00785.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00787.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00789.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00790.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00793.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00795.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00796.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00799.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00800.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00803.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00805.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00806.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00808.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00809.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00811.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00814.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00815.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00816.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00818.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00820.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00822.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00826.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00828.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00829.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00830.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00831.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00832.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00833.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00834.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00836.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00838.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00839.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00840.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00843.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00844.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00846.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00848.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00850.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00852.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00854.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00855.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00858.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00859.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00861.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00863.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00865.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00867.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00869.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00871.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00874.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00875.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00877.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00878.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00882.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00883.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00886.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00887.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00889.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00892.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00895.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00897.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00899.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00900.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00902.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00904.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00906.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00907.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00909.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00911.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00913.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00915.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00917.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00920.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00921.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00923.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00925.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00927.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00929.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00937.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00938.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00941.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00942.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00945.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00946.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00949.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00951.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00953.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00954.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00956.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00958.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00959.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00961.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00963.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00965.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00967.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00969.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00971.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00973.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00976.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00978.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00981.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00982.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00984.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00985.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00991.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00992.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00993.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00994.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00995.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_00996.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01000.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01001.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01004.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01013.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01014.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01017.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01018.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01020.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01023.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01024.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01027.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01028.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01029.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01030.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01031.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01032.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01033.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_01038.jpg
#   inflating: /content/Data/Green mirid bug/green_mirid_bug_
#   inflating: /content/Data/Red spider/red_spider_00510.jpg
#   inflating: /content/Data/Red spider/red_spider_00511.jpg
#   inflating: /content/Data/Red spider/red_spider_00512.jpg
#   inflating: /content/Data/Red spider/red_spider_00513.jpg
#   inflating: /content/Data/Red spider/red_spider_00514.jpg
#   inflating: /content/Data/Red spider/red_spider_00515.jpg
# Stratified split completed.
#
#
#  TRAIN
#   Algal leaf spot: 910
#   Brown blight: 823
#   Gray blight: 1127
#   Green mirid bug: 587
#   Healthy: 1238
#   Helopeltis: 917
#   Red leaf spot: 700
#   Red spider: 293
#
#  VAL
#   Algal leaf spot: 195
#   Brown blight: 176
#   Gray blight: 242
#   Green mirid bug: 126
#   Healthy: 265
#   Helopeltis: 197
#   Red leaf spot: 150
#   Red spider: 63
#
#  TEST
#   Algal leaf spot: 196
#   Brown blight: 177
#   Gray blight: 242
#   Green mirid bug: 126
#   Healthy: 266
#   Helopeltis: 197
#   Red leaf spot: 150
#   Red spider: 63

# %%
import os
import random
import shutil
import hashlib

# Print class distribution
base = "/content/drive/MyDrive/Dataset"
for split in ["train", "val", "test"]:
    print(f"\n {split.upper()}")
    for cls in sorted(os.listdir(os.path.join(base, split))):
        count = len(os.listdir(os.path.join(base, split, cls)))
        print(f"  {cls}: {count}")
# Out:
#  TRAIN
#   Algal leaf spot: 910
#   Brown blight: 823
#   Gray blight: 1127
#   Green mirid bug: 587
#   Healthy: 1238
#   Helopeltis: 917
#   Red leaf spot: 700
#   Red spider: 293
#
#  VAL
#   Algal leaf spot: 195
#   Brown blight: 176
#   Gray blight: 242
#   Green mirid bug: 126
#   Healthy: 265
#   Helopeltis: 197
#   Red leaf spot: 150
#   Red spider: 63
#
#  TEST
#   Algal leaf spot: 196
#   Brown blight: 177
#   Gray blight: 242
#   Green mirid bug: 126
#   Healthy: 266
#   Helopeltis: 197
#   Red leaf spot: 150
#   Red spider: 63

# %%
# Verify no leakage
def get_all_hashes(folder):
    hashes = set()
    for cls in os.listdir(folder):
        for img in os.listdir(os.path.join(folder, cls)):
            path = os.path.join(folder, cls, img)
            with open(path, 'rb') as f:
                hashes.add(hashlib.md5(f.read()).hexdigest())
    return hashes

train_h = get_all_hashes(os.path.join(base, "train"))
val_h   = get_all_hashes(os.path.join(base, "val"))
test_h  = get_all_hashes(os.path.join(base, "test"))

print(f"\nLeakage check:")
print(f"  Train ∩ Val  : {len(train_h & val_h)}  (must be 0)")
print(f"  Train ∩ Test : {len(train_h & test_h)} (must be 0)")
print(f"  Val   ∩ Test : {len(val_h   & test_h)} (must be 0)")
# Out:
# Leakage check:
#   Train ∩ Val  : 0  (must be 0)
#   Train ∩ Test : 0 (must be 0)
#   Val   ∩ Test : 0 (must be 0)

# %%
# ─────────────────────────────────────────────
# 2. IMPORTS & DEVICE
# ─────────────────────────────────────────────
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import (DataLoader, WeightedRandomSampler,
                               Subset, ConcatDataset)
from torchvision import datasets, transforms, models
from torchvision.models import MobileNet_V2_Weights, ResNet50_Weights
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import copy

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\nUsing device: {device}")
# Out:
# Using device: cuda

# %%
# ─────────────────────────────────────────────
# 3. DATA TRANSFORMS & LOADERS
# ─────────────────────────────────────────────
train_dir = "/content/drive/MyDrive/Dataset/train"
val_dir   = "/content/drive/MyDrive/Dataset/val"
test_dir  = "/content/drive/MyDrive/Dataset/test"

input_size = 224

train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(input_size, scale=(0.7, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
    transforms.RandomRotation(20),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

val_test_transforms = transforms.Compose([
    transforms.Resize((input_size, input_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# TTA (Test-Time Augmentation) transform — used at inference
tta_transforms = transforms.Compose([
    transforms.Resize((input_size, input_size)),
    transforms.RandomHorizontalFlip(p=1.0),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Full train dataset with augmentation (used during fold training)
full_train_aug  = datasets.ImageFolder(train_dir, transform=train_transforms)
# Full train dataset without augmentation (used during OOF prediction)
full_train_base = datasets.ImageFolder(train_dir, transform=val_test_transforms)

val_dataset   = datasets.ImageFolder(val_dir,   transform=val_test_transforms)
test_dataset  = datasets.ImageFolder(test_dir,  transform=val_test_transforms)
test_dataset_tta = datasets.ImageFolder(test_dir, transform=tta_transforms)

num_classes  = len(full_train_aug.classes)
print(f"Classes ({num_classes}):", full_train_aug.classes)

# All train labels (needed for StratifiedKFold)
all_train_labels = np.array([s[1] for s in full_train_aug.samples])
n_train          = len(all_train_labels)
print(f"Total train samples: {n_train}")
# Out:
# Classes (8): ['Algal leaf spot', 'Brown blight', 'Gray blight', 'Green mirid bug', 'Healthy', 'Helopeltis', 'Red leaf spot', 'Red spider']
# Total train samples: 6595

# %%
# ─────────────────────────────────────────────
# 4. CLASS WEIGHTS + WEIGHTED SAMPLER
# ─────────────────────────────────────────────
class_counts = {
    "Helopeltis":     917,
    "Algal leaf spot":910,
    "Red spider":     293,
    "Red leaf spot":  700,
    "Healthy":        1238,
    "Gray blight":    1127,
    "Brown blight":   823,
    "Green mirid bug":587
}

class_to_idx   = full_train_aug.class_to_idx
total_samples  = sum(class_counts.values())
weights        = [0.0] * num_classes

for class_name, idx in class_to_idx.items():
    weights[idx] = total_samples / (num_classes * class_counts[class_name])

class_weights = torch.tensor(weights, dtype=torch.float).to(device)
print("Class weights:", {k: f"{v:.3f}" for k, v in zip(full_train_aug.classes, weights)})

batch_size   = 32

val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False,
                          num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size, shuffle=False,
                          num_workers=2, pin_memory=True)
test_loader_tta = DataLoader(test_dataset_tta, batch_size=batch_size, shuffle=False,
                             num_workers=2, pin_memory=True)
# Out:
# Class weights: {'Algal leaf spot': '0.906', 'Brown blight': '1.002', 'Gray blight': '0.731', 'Green mirid bug': '1.404', 'Healthy': '0.666', 'Helopeltis': '0.899', 'Red leaf spot': '1.178', 'Red spider': '2.814'}

# %%
# ─────────────────────────────────────────────
# 5. ECA ATTENTION MODULE
# ─────────────────────────────────────────────
class ECALayer(nn.Module):
    """Efficient Channel Attention — lightweight channel recalibration."""
    def __init__(self, channel, k_size=3):
        super().__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.conv     = nn.Conv1d(1, 1, kernel_size=k_size,
                                  padding=(k_size - 1) // 2, bias=False)
        self.sigmoid  = nn.Sigmoid()

    def forward(self, x):
        y = self.avg_pool(x)                          # (B, C, 1, 1)
        y = self.conv(y.squeeze(-1).transpose(-1,-2)) # (B, 1, C)
        y = self.sigmoid(y).transpose(-1,-2).unsqueeze(-1)  # (B, C, 1, 1)
        return x * y.expand_as(x)

# %%
# ─────────────────────────────────────────────
# 6. MODEL BUILDERS
# ─────────────────────────────────────────────
def build_mobilenetv2(num_classes, pretrained=True):
    w     = MobileNet_V2_Weights.DEFAULT if pretrained else None
    model = models.mobilenet_v2(weights=w)
    model.features.add_module("eca", ECALayer(model.last_channel))
    model.classifier = nn.Sequential(
        nn.Dropout(0.4),
        nn.Linear(model.last_channel, 256),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(256, num_classes)
    )
    return model.to(device)


def build_resnet50(num_classes, pretrained=True):
    w     = ResNet50_Weights.DEFAULT if pretrained else None
    model = models.resnet50(weights=w)

    class Layer4WithECA(nn.Module):
        def __init__(self, layer4, eca):
            super().__init__()
            self.layer4 = layer4
            self.eca    = eca
        def forward(self, x):
            return self.eca(self.layer4(x))

    model.layer4 = Layer4WithECA(model.layer4, ECALayer(2048))
    model.fc     = nn.Sequential(
        nn.Dropout(0.4),
        nn.Linear(model.fc.in_features, num_classes)
    )
    return model.to(device)

# %%
# ─────────────────────────────────────────────
# 7. FREEZE / UNFREEZE HELPERS
# ─────────────────────────────────────────────

def freeze_backbone(model, model_name):
    """Freeze all layers except the classifier head."""
    if model_name == "mobilenetv2":
        for p in model.features.parameters():
            p.requires_grad = False
    else:  # resnet50
        for n, p in model.named_parameters():
            if "fc" not in n:
                p.requires_grad = False
    t = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"  [Frozen]  Trainable: {t:,}")


def unfreeze_partial(model, model_name, unfreeze_last_n_blocks=2):
    """
    Unfreeze partial backbone for fine-tuning.
    MobileNetV2 : last 4 inverted residual blocks + classifier
    ResNet50    : layer4 + fc always, layer3 if unfreeze_last_n_blocks >= 2
    """
    if model_name == "mobilenetv2":
        for block in list(model.features.children())[-4:]:
            for p in block.parameters():
                p.requires_grad = True
        for p in model.classifier.parameters():
            p.requires_grad = True
    else:  # resnet50
        target_layers = ["layer4", "fc"]
        if unfreeze_last_n_blocks >= 2:
            target_layers.append("layer3")
        for n, p in model.named_parameters():
            if any(x in n for x in target_layers):
                p.requires_grad = True
    t = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"  [Partial] Trainable: {t:,}")

# %%
# ─────────────────────────────────────────────
# 8. TRAINING LOOP
# ─────────────────────────────────────────────
def train_one_phase(model, train_loader, val_loader,
                   num_epochs, lr, save_path,
                   phase_label="Phase", patience=5):

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()), lr=lr
    )
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', patience=3, factor=0.5
    )

    best_val_acc  = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())
    patience_counter = 0

    history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

    for epoch in range(num_epochs):

        # ── TRAIN ──────────────────────────────
        model.train()
        running_loss, correct, total = 0.0, 0, 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss    = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted  = torch.max(outputs, 1)
            total        += labels.size(0)
            correct      += (predicted == labels).sum().item()

        train_loss = running_loss / total
        train_acc  = 100 * correct / total

        # ── VALIDATE ───────────────────────────
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs        = model(images)
                loss           = criterion(outputs, labels)
                val_loss      += loss.item() * images.size(0)
                _, predicted   = torch.max(outputs, 1)
                val_total     += labels.size(0)
                val_correct   += (predicted == labels).sum().item()

        val_loss /= val_total
        val_acc   = 100 * val_correct / val_total
        current_lr = optimizer.param_groups[0]['lr']

        scheduler.step(val_loss)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        print(f"[{phase_label}] Epoch [{epoch+1}/{num_epochs}] "
              f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | "
              f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}% | LR: {current_lr:.6f}")

        # Save best
        if val_acc > best_val_acc:
            best_val_acc   = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), save_path)
            print(f"  ✓ Saved best model (val_acc={val_acc:.2f}%)")
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"  Early stopping triggered at epoch {epoch+1}.")
                break

    model.load_state_dict(best_model_wts)
    return model, history, best_val_acc

# %%
# ─────────────────────────────────────────────
# 9.  OOF Probability Extractor
# ─────────────────────────────────────────────
def get_oof_probs(model, subset_indices, base_dataset):
    """
    Run inference on a subset of the train set (the held-out OOF fold).
    Uses clean base_transforms (no augmentation).
    Returns probs (N_fold, num_classes) and labels (N_fold,).
    """
    model.eval()
    subset  = Subset(base_dataset, subset_indices)
    loader  = DataLoader(subset, batch_size=32,
                         shuffle=False, num_workers=2)
    probs_list, labels_list = [], []
    with torch.no_grad():
        for imgs, lbls in loader:
            imgs = imgs.to(device)
            p    = F.softmax(model(imgs), dim=1).cpu()
            probs_list.append(p)
            labels_list.extend(lbls.numpy())
    return (torch.cat(probs_list).numpy(),
            np.array(labels_list))

# %%
# ─────────────────────────────────────────────
# 10. EVALUATION
# ─────────────────────────────────────────────

def evaluate_final(model, test_loader, test_loader_tta,
                   class_names, model_name):
    model.eval()
    base_probs, tta_probs, all_labels = [], [], []
    with torch.no_grad():
        for (imgs, lbls), (imgs_t, _) in zip(test_loader,
                                             test_loader_tta):
            base_probs.append(
                F.softmax(model(imgs.to(device)),   dim=1).cpu())
            tta_probs.append(
                F.softmax(model(imgs_t.to(device)), dim=1).cpu())
            all_labels.extend(lbls.numpy())

    probs  = (torch.cat(base_probs) + torch.cat(tta_probs)) / 2.0
    preds  = probs.argmax(1).numpy()
    labels = np.array(all_labels)
    acc    = (preds == labels).mean() * 100

    print(f"\nFinal Test Accuracy (TTA): {acc:.2f}%")
    print(classification_report(labels, preds,
                                target_names=class_names))

    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted"); plt.ylabel("Actual")
    plt.title(f"Confusion Matrix — {model_name}")
    plt.tight_layout()
    plt.savefig(
        f"/content/drive/MyDrive/cm_{model_name}.png", dpi=150)
    plt.show()
    return acc, labels, preds

# %%
# ─────────────────────────────────────────────
# 10. PLOT TRAINING CURVES
# ─────────────────────────────────────────────
def plot_history(history_p1, history_p2=None, model_name="model"):
    epochs_p1 = range(1, len(history_p1["train_acc"]) + 1)

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Accuracy
    axes[0].plot(epochs_p1, history_p1["train_acc"], label="Train Acc (P1)")
    axes[0].plot(epochs_p1, history_p1["val_acc"],   label="Val Acc (P1)")
    if history_p2:
        epochs_p2 = range(len(epochs_p1) + 1,
                          len(epochs_p1) + len(history_p2["train_acc"]) + 1)
        axes[0].plot(epochs_p2, history_p2["train_acc"], "--", label="Train Acc (P2)")
        axes[0].plot(epochs_p2, history_p2["val_acc"],   "--", label="Val Acc (P2)")
    axes[0].set_title("Accuracy")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("%")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # Loss
    axes[1].plot(epochs_p1, history_p1["train_loss"], label="Train Loss (P1)")
    axes[1].plot(epochs_p1, history_p1["val_loss"],   label="Val Loss (P1)")
    if history_p2:
        axes[1].plot(epochs_p2, history_p2["train_loss"], "--", label="Train Loss (P2)")
        axes[1].plot(epochs_p2, history_p2["val_loss"],   "--", label="Val Loss (P2)")
    axes[1].set_title("Loss")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Loss")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.suptitle(f"Training History — {model_name}", fontsize=13)
    plt.tight_layout()
    plt.savefig(f"training_history_{model_name}.png", dpi=150)
    plt.show()

# %%
# ─────────────────────────────────────────────
# 11. MAIN — SELECT & TRAIN YOUR MODEL
# ─────────────────────────────────────────────

# ── Change this to "mobilenetv2" or "resnet50" ──
model_name = "resnet50"

save_path  = f"/content/drive/MyDrive/fine_tuned_best_{model_name}_eca.pth"



# ── PHASE 3 (optional): Full fine-tune with very low LR ──
# Uncomment if you want to squeeze out more accuracy
# unfreeze_backbone(model, model_name, unfreeze_last_n_blocks=99)  # all layers
# model, history_p3 = train_model(
#     model, model_name, train_loader, val_loader,
#     num_epochs=10, lr=5e-5, save_path=save_path,
#     phase_label="P3", patience=5
# )

# %%
# ─────────────────────────────────────────────
# 12. OOF Training Loop (5-Fold)
# ─────────────────────────────────────────────
"""
What happens here:
  For each of 5 folds:
    1. Split train indices into fold_train and fold_val
    2. Build a fresh pretrained model
    3. Phase 1: freeze backbone, train head (10 epochs)
    4. Phase 2: unfreeze partial, fine-tune (15 epochs)
    5. Predict on fold_val using clean (no-aug) images
    6. Store these OOF probabilities

After all folds:
  oof_probs   shape: (n_train, 8)  ← realistic probs for ALL train images
  oof_labels  shape: (n_train,)    ← true labels for all train images
  oof_indices shape: (n_train,)    ← original dataset indices

These get saved to Drive for use in Notebook 3.
"""

N_FOLDS  = 5
skf      = StratifiedKFold(n_splits=N_FOLDS, shuffle=True,
                            random_state=42)

# Pre-allocate OOF arrays
oof_probs   = np.zeros((n_train, num_classes), dtype=np.float32)
oof_labels  = np.zeros(n_train, dtype=np.int64)
oof_indices = np.zeros(n_train, dtype=np.int64)

indices = np.arange(n_train)

for fold, (fold_train_idx, fold_val_idx) in enumerate(
        skf.split(indices, all_train_labels)):

    print(f"\n{'─'*55}")
    print(f"  FOLD {fold+1}/{N_FOLDS} | "
          f"Train: {len(fold_train_idx)} | Val: {len(fold_val_idx)}")
    print(f"{'─'*55}")

    # ── Build loaders for this fold ──
    fold_train_subset = Subset(full_train_aug,  fold_train_idx)
    fold_val_subset   = Subset(full_train_base, fold_val_idx)

    # Weighted sampler for fold train subset
    fold_sample_w = [weights[all_train_labels[i]]
                     for i in fold_train_idx]
    fold_sampler  = WeightedRandomSampler(
        fold_sample_w, len(fold_sample_w), replacement=True
    )

    fold_train_loader = DataLoader(fold_train_subset,
                                   batch_size=32,
                                   sampler=fold_sampler,
                                   num_workers=2)
    fold_val_loader   = DataLoader(fold_val_subset,
                                   batch_size=32,
                                   shuffle=False,
                                   num_workers=2)

    # ── Build fresh model ──
    if model_name == "mobilenetv2":
        model = build_mobilenetv2(num_classes, pretrained=True)
    else:
        model = build_resnet50(num_classes, pretrained=True)

    fold_save = f"/content/drive/MyDrive/fold{fold+1}_{model_name}.pth"

    # ── Phase 1: head only ──
    print(f"\n  Phase 1 — Head only")
    freeze_backbone(model, model_name)
    model, _, _ = train_one_phase(
        model, fold_train_loader, fold_val_loader,
        num_epochs=10, lr=1e-3,
        save_path=fold_save,
        phase_label=f"F{fold+1}-P1",
        patience=3
    )

    # ── Phase 2: partial unfreeze ──
    print(f"\n  Phase 2 — Partial unfreeze")
    unfreeze_partial(model, model_name)
    model, _, _ = train_one_phase(
        model, fold_train_loader, fold_val_loader,
        num_epochs=15, lr=1e-4,
        save_path=fold_save,
        phase_label=f"F{fold+1}-P2",
        patience=4
    )

    # ── OOF Prediction on held-out fold ──
    print(f"\n  Extracting OOF predictions for fold {fold+1}...")
    fold_probs, fold_lbls = get_oof_probs(
        model, fold_val_idx, full_train_base
    )

    # Store in pre-allocated arrays
    oof_probs[fold_val_idx]   = fold_probs
    oof_labels[fold_val_idx]  = fold_lbls
    oof_indices[fold_val_idx] = fold_val_idx

    fold_acc = (fold_probs.argmax(1) == fold_lbls).mean() * 100
    print(f"  Fold {fold+1} OOF accuracy: {fold_acc:.2f}%")

    # Save fold checkpoint (optional, for recovery)
    print(f"  Fold {fold+1} done. Checkpoint: {fold_save}")

# Overall OOF accuracy
oof_preds    = oof_probs.argmax(1)
overall_oof  = (oof_preds == oof_labels).mean() * 100
print(f"\n{'='*55}")
print(f"Overall OOF Accuracy ({N_FOLDS}-fold): {overall_oof:.2f}%")
print(f"{'='*55}")

# Save OOF outputs to Drive
np.save(f"/content/drive/MyDrive/oof_{model_name}_probs.npy",   oof_probs)
np.save(f"/content/drive/MyDrive/oof_{model_name}_labels.npy",  oof_labels)
np.save(f"/content/drive/MyDrive/oof_{model_name}_indices.npy", oof_indices)
print(f"OOF arrays saved to Drive.")
# Out:
# ───────────────────────────────────────────────────────
#   FOLD 1/5 | Train: 5276 | Val: 1319
# ───────────────────────────────────────────────────────
#
#   Phase 1 — Head only
#   [Frozen]  Trainable: 16,392
# [F1-P1] Epoch [1/10] Train Loss: 1.6088 | Train Acc: 32.56% | Val Loss: 1.6147 | Val Acc: 42.91% | LR: 0.001000
#   ✓ Saved best model (val_acc=42.91%)
# [F1-P1] Epoch [2/10] Train Loss: 1.2340 | Train Acc: 53.13% | Val Loss: 1.3659 | Val Acc: 53.37% | LR: 0.001000
#   ✓ Saved best model (val_acc=53.37%)
# [F1-P1] Epoch [3/10] Train Loss: 1.0844 | Train Acc: 59.86% | Val Loss: 1.2259 | Val Acc: 61.03% | LR: 0.001000
#   ✓ Saved best model (val_acc=61.03%)
# [F1-P1] Epoch [4/10] Train Loss: 0.9899 | Train Acc: 62.64% | Val Loss: 1.1405 | Val Acc: 62.93% | LR: 0.001000
#   ✓ Saved best model (val_acc=62.93%)
# [F1-P1] Epoch [5/10] Train Loss: 0.9362 | Train Acc: 64.03% | Val Loss: 1.0409 | Val Acc: 65.88% | LR: 0.001000
#   ✓ Saved best model (val_acc=65.88%)
# [F1-P1] Epoch [6/10] Train Loss: 0.9161 | Train Acc: 65.31% | Val Loss: 1.0084 | Val Acc: 67.10% | LR: 0.001000
#   ✓ Saved best model (val_acc=67.10%)
# [F1-P1] Epoch [7/10] Train Loss: 0.8752 | Train Acc: 66.28% | Val Loss: 0.9389 | Val Acc: 68.92% | LR: 0.001000
#   ✓ Saved best model (val_acc=68.92%)
# [F1-P1] Epoch [8/10] Train Loss: 0.8402 | Train Acc: 66.93% | Val Loss: 0.9315 | Val Acc: 69.52% | LR: 0.001000
#   ✓ Saved best model (val_acc=69.52%)
# [F1-P1] Epoch [9/10] Train Loss: 0.8141 | Train Acc: 68.12% | Val Loss: 0.8940 | Val Acc: 70.81% | LR: 0.001000
#   ✓ Saved best model (val_acc=70.81%)
# [F1-P1] Epoch [10/10] Train Loss: 0.8199 | Train Acc: 66.98% | Val Loss: 0.8550 | Val Acc: 72.25% | LR: 0.001000
#   ✓ Saved best model (val_acc=72.25%)
#
#   Phase 2 — Partial unfreeze
#   [Partial] Trainable: 22,079,499
# [F1-P2] Epoch [1/15] Train Loss: 0.5069 | Train Acc: 79.53% | Val Loss: 0.3280 | Val Acc: 87.95% | LR: 0.000100
#   ✓ Saved best model (val_acc=87.95%)
# [F1-P2] Epoch [2/15] Train Loss: 0.2888 | Train Acc: 88.00% | Val Loss: 0.2964 | Val Acc: 88.86% | LR: 0.000100
#   ✓ Saved best model (val_acc=88.86%)
# [F1-P2] Epoch [3/15] Train Loss: 0.2276 | Train Acc: 90.16% | Val Loss: 0.2107 | Val Acc: 92.27% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.27%)
# [F1-P2] Epoch [4/15] Train Loss: 0.2130 | Train Acc: 91.55% | Val Loss: 0.2273 | Val Acc: 92.27% | LR: 0.000100
# [F1-P2] Epoch [5/15] Train Loss: 0.1894 | Train Acc: 91.87% | Val Loss: 0.1733 | Val Acc: 93.18% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.18%)
# [F1-P2] Epoch [6/15] Train Loss: 0.1499 | Train Acc: 93.61% | Val Loss: 0.1699 | Val Acc: 93.93% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.93%)
# [F1-P2] Epoch [7/15] Train Loss: 0.1467 | Train Acc: 93.86% | Val Loss: 0.1718 | Val Acc: 93.86% | LR: 0.000100
# [F1-P2] Epoch [8/15] Train Loss: 0.1283 | Train Acc: 94.60% | Val Loss: 0.1596 | Val Acc: 94.01% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.01%)
# [F1-P2] Epoch [9/15] Train Loss: 0.1261 | Train Acc: 94.52% | Val Loss: 0.1517 | Val Acc: 94.62% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.62%)
# [F1-P2] Epoch [10/15] Train Loss: 0.1098 | Train Acc: 95.38% | Val Loss: 0.1473 | Val Acc: 95.07% | LR: 0.000100
#   ✓ Saved best model (val_acc=95.07%)
# [F1-P2] Epoch [11/15] Train Loss: 0.1002 | Train Acc: 95.75% | Val Loss: 0.2008 | Val Acc: 93.63% | LR: 0.000100
# [F1-P2] Epoch [12/15] Train Loss: 0.1004 | Train Acc: 95.79% | Val Loss: 0.1297 | Val Acc: 95.68% | LR: 0.000100
#   ✓ Saved best model (val_acc=95.68%)
# [F1-P2] Epoch [13/15] Train Loss: 0.0999 | Train Acc: 95.87% | Val Loss: 0.1622 | Val Acc: 94.69% | LR: 0.000100
# [F1-P2] Epoch [14/15] Train Loss: 0.0973 | Train Acc: 95.81% | Val Loss: 0.1358 | Val Acc: 95.30% | LR: 0.000100
# [F1-P2] Epoch [15/15] Train Loss: 0.0961 | Train Acc: 96.04% | Val Loss: 0.1558 | Val Acc: 95.38% | LR: 0.000100
#
#   Extracting OOF predictions for fold 1...
#   Fold 1 OOF accuracy: 95.68%
#   Fold 1 done. Checkpoint: /content/drive/MyDrive/fold1_resnet50.pth
#
# ───────────────────────────────────────────────────────
#   FOLD 2/5 | Train: 5276 | Val: 1319
# ───────────────────────────────────────────────────────
#
#   Phase 1 — Head only
#   [Frozen]  Trainable: 16,392
# [F2-P1] Epoch [1/10] Train Loss: 1.6560 | Train Acc: 29.74% | Val Loss: 1.6838 | Val Acc: 38.89% | LR: 0.001000
#   ✓ Saved best model (val_acc=38.89%)
# [F2-P1] Epoch [2/10] Train Loss: 1.2783 | Train Acc: 51.10% | Val Loss: 1.4045 | Val Acc: 52.84% | LR: 0.001000
#   ✓ Saved best model (val_acc=52.84%)
# [F2-P1] Epoch [3/10] Train Loss: 1.1204 | Train Acc: 58.19% | Val Loss: 1.2562 | Val Acc: 61.03% | LR: 0.001000
#   ✓ Saved best model (val_acc=61.03%)
# [F2-P1] Epoch [4/10] Train Loss: 1.0390 | Train Acc: 60.88% | Val Loss: 1.1821 | Val Acc: 61.11% | LR: 0.001000
#   ✓ Saved best model (val_acc=61.11%)
# [F2-P1] Epoch [5/10] Train Loss: 0.9694 | Train Acc: 62.32% | Val Loss: 1.0816 | Val Acc: 66.03% | LR: 0.001000
#   ✓ Saved best model (val_acc=66.03%)
# [F2-P2] Epoch [13/15] Train Loss: 0.0985 | Train Acc: 95.77% | Val Loss: 0.2325 | Val Acc: 93.48% | LR: 0.000100
# [F2-P2] Epoch [14/15] Train Loss: 0.0919 | Train Acc: 96.23% | Val Loss: 0.1886 | Val Acc: 94.54% | LR: 0.000100
# [F2-P2] Epoch [15/15] Train Loss: 0.0809 | Train Acc: 96.44% | Val Loss: 0.1757 | Val Acc: 94.31% | LR: 0.000100
#   Early stopping triggered at epoch 15.
#
#   Extracting OOF predictions for fold 2...
#   Fold 2 OOF accuracy: 95.07%
#   Fold 2 done. Checkpoint: /content/drive/MyDrive/fold2_resnet50.pth
#
# ───────────────────────────────────────────────────────
#   FOLD 3/5 | Train: 5276 | Val: 1319
# ───────────────────────────────────────────────────────
#
#   Phase 1 — Head only
#   [Frozen]  Trainable: 16,392
# [F3-P1] Epoch [1/10] Train Loss: 1.5775 | Train Acc: 33.42% | Val Loss: 1.5454 | Val Acc: 44.35% | LR: 0.001000
#   ✓ Saved best model (val_acc=44.35%)
# [F3-P1] Epoch [2/10] Train Loss: 1.1925 | Train Acc: 54.81% | Val Loss: 1.3127 | Val Acc: 57.16% | LR: 0.001000
#   ✓ Saved best model (val_acc=57.16%)
# [F3-P1] Epoch [3/10] Train Loss: 1.0524 | Train Acc: 60.86% | Val Loss: 1.1212 | Val Acc: 64.90% | LR: 0.001000
#   ✓ Saved best model (val_acc=64.90%)
# [F3-P1] Epoch [4/10] Train Loss: 0.9525 | Train Acc: 63.76% | Val Loss: 1.1145 | Val Acc: 63.15% | LR: 0.001000
# [F3-P1] Epoch [5/10] Train Loss: 0.9230 | Train Acc: 64.58% | Val Loss: 1.0027 | Val Acc: 68.08% | LR: 0.001000
#   ✓ Saved best model (val_acc=68.08%)
# [F3-P1] Epoch [6/10] Train Loss: 0.8754 | Train Acc: 66.38% | Val Loss: 0.9754 | Val Acc: 68.23% | LR: 0.001000
#   ✓ Saved best model (val_acc=68.23%)
# [F3-P1] Epoch [7/10] Train Loss: 0.8740 | Train Acc: 65.79% | Val Loss: 0.9644 | Val Acc: 68.01% | LR: 0.001000
# [F3-P1] Epoch [8/10] Train Loss: 0.8267 | Train Acc: 67.51% | Val Loss: 0.9129 | Val Acc: 70.05% | LR: 0.001000
#   ✓ Saved best model (val_acc=70.05%)
# [F3-P1] Epoch [9/10] Train Loss: 0.8087 | Train Acc: 68.54% | Val Loss: 0.8726 | Val Acc: 70.74% | LR: 0.001000
#   ✓ Saved best model (val_acc=70.74%)
# [F3-P1] Epoch [10/10] Train Loss: 0.7936 | Train Acc: 68.35% | Val Loss: 0.8511 | Val Acc: 71.80% | LR: 0.001000
#   ✓ Saved best model (val_acc=71.80%)
#
#   Phase 2 — Partial unfreeze
#   [Partial] Trainable: 22,079,499
# [F3-P2] Epoch [1/15] Train Loss: 0.4902 | Train Acc: 80.02% | Val Loss: 0.4129 | Val Acc: 85.67% | LR: 0.000100
#   ✓ Saved best model (val_acc=85.67%)
# [F3-P2] Epoch [2/15] Train Loss: 0.3105 | Train Acc: 87.00% | Val Loss: 0.2768 | Val Acc: 90.45% | LR: 0.000100
#   ✓ Saved best model (val_acc=90.45%)
# [F3-P2] Epoch [3/15] Train Loss: 0.2379 | Train Acc: 90.16% | Val Loss: 0.2709 | Val Acc: 91.21% | LR: 0.000100
#   ✓ Saved best model (val_acc=91.21%)
# [F3-P2] Epoch [4/15] Train Loss: 0.1946 | Train Acc: 91.58% | Val Loss: 0.2219 | Val Acc: 92.27% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.27%)
# [F3-P2] Epoch [5/15] Train Loss: 0.1730 | Train Acc: 92.55% | Val Loss: 0.1977 | Val Acc: 92.42% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.42%)
# [F3-P2] Epoch [6/15] Train Loss: 0.1687 | Train Acc: 92.99% | Val Loss: 0.2010 | Val Acc: 92.57% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.57%)
# [F3-P2] Epoch [7/15] Train Loss: 0.1309 | Train Acc: 94.62% | Val Loss: 0.2111 | Val Acc: 92.87% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.87%)
# [F3-P2] Epoch [8/15] Train Loss: 0.1274 | Train Acc: 94.73% | Val Loss: 0.1632 | Val Acc: 93.63% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.63%)
# [F3-P2] Epoch [9/15] Train Loss: 0.1185 | Train Acc: 94.83% | Val Loss: 0.1888 | Val Acc: 93.40% | LR: 0.000100
# [F3-P2] Epoch [10/15] Train Loss: 0.1093 | Train Acc: 95.30% | Val Loss: 0.1831 | Val Acc: 93.78% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.78%)
# [F3-P2] Epoch [11/15] Train Loss: 0.0961 | Train Acc: 95.89% | Val Loss: 0.1715 | Val Acc: 94.47% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.47%)
# [F3-P2] Epoch [12/15] Train Loss: 0.0958 | Train Acc: 95.94% | Val Loss: 0.2054 | Val Acc: 93.40% | LR: 0.000100
# [F3-P2] Epoch [13/15] Train Loss: 0.0866 | Train Acc: 96.44% | Val Loss: 0.1458 | Val Acc: 95.53% | LR: 0.000050
#   ✓ Saved best model (val_acc=95.53%)
# [F3-P2] Epoch [14/15] Train Loss: 0.0744 | Train Acc: 96.85% | Val Loss: 0.1548 | Val Acc: 95.53% | LR: 0.000050
# [F3-P2] Epoch [15/15] Train Loss: 0.0750 | Train Acc: 96.97% | Val Loss: 0.1559 | Val Acc: 95.07% | LR: 0.000050
#
#   Extracting OOF predictions for fold 3...
#   Fold 3 OOF accuracy: 95.53%
#   Fold 3 done. Checkpoint: /content/drive/MyDrive/fold3_resnet50.pth
#
# ───────────────────────────────────────────────────────
#   FOLD 4/5 | Train: 5276 | Val: 1319
# ───────────────────────────────────────────────────────
#
#   Phase 1 — Head only
#   [Frozen]  Trainable: 16,392
# [F4-P1] Epoch [1/10] Train Loss: 1.5949 | Train Acc: 33.06% | Val Loss: 1.5751 | Val Acc: 48.60% | LR: 0.001000
#   ✓ Saved best model (val_acc=48.60%)
# [F4-P1] Epoch [2/10] Train Loss: 1.2235 | Train Acc: 54.09% | Val Loss: 1.3059 | Val Acc: 59.29% | LR: 0.001000
#   ✓ Saved best model (val_acc=59.29%)
# [F4-P1] Epoch [3/10] Train Loss: 1.0781 | Train Acc: 59.97% | Val Loss: 1.1554 | Val Acc: 64.75% | LR: 0.001000
#   ✓ Saved best model (val_acc=64.75%)
# [F4-P1] Epoch [4/10] Train Loss: 0.9931 | Train Acc: 63.17% | Val Loss: 1.0742 | Val Acc: 66.03% | LR: 0.001000
#   ✓ Saved best model (val_acc=66.03%)
# [F4-P1] Epoch [5/10] Train Loss: 0.9297 | Train Acc: 64.50% | Val Loss: 1.0263 | Val Acc: 67.17% | LR: 0.001000
#   ✓ Saved best model (val_acc=67.17%)
# [F4-P1] Epoch [6/10] Train Loss: 0.9014 | Train Acc: 66.26% | Val Loss: 0.9603 | Val Acc: 69.60% | LR: 0.001000
#   ✓ Saved best model (val_acc=69.60%)
# [F4-P1] Epoch [7/10] Train Loss: 0.8471 | Train Acc: 67.19% | Val Loss: 0.9283 | Val Acc: 70.58% | LR: 0.001000
#   ✓ Saved best model (val_acc=70.58%)
# [F4-P1] Epoch [8/10] Train Loss: 0.8292 | Train Acc: 68.46% | Val Loss: 0.8966 | Val Acc: 71.95% | LR: 0.001000
#   ✓ Saved best model (val_acc=71.95%)
# [F4-P1] Epoch [9/10] Train Loss: 0.8226 | Train Acc: 67.61% | Val Loss: 0.8959 | Val Acc: 72.02% | LR: 0.001000
#   ✓ Saved best model (val_acc=72.02%)
# [F4-P1] Epoch [10/10] Train Loss: 0.7748 | Train Acc: 68.73% | Val Loss: 0.8897 | Val Acc: 72.18% | LR: 0.001000
#   ✓ Saved best model (val_acc=72.18%)
#
#   Phase 2 — Partial unfreeze
#   [Partial] Trainable: 22,079,499
# [F4-P2] Epoch [1/15] Train Loss: 0.4526 | Train Acc: 80.69% | Val Loss: 0.3329 | Val Acc: 87.26% | LR: 0.000100
#   ✓ Saved best model (val_acc=87.26%)
# [F4-P2] Epoch [2/15] Train Loss: 0.2914 | Train Acc: 87.74% | Val Loss: 0.2794 | Val Acc: 89.39% | LR: 0.000100
#   ✓ Saved best model (val_acc=89.39%)
# [F4-P2] Epoch [3/15] Train Loss: 0.2262 | Train Acc: 90.33% | Val Loss: 0.2748 | Val Acc: 90.67% | LR: 0.000100
#   ✓ Saved best model (val_acc=90.67%)
# [F4-P2] Epoch [4/15] Train Loss: 0.1812 | Train Acc: 92.59% | Val Loss: 0.2040 | Val Acc: 92.65% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.65%)
# [F4-P2] Epoch [5/15] Train Loss: 0.1610 | Train Acc: 92.84% | Val Loss: 0.1905 | Val Acc: 92.95% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.95%)
# [F4-P2] Epoch [6/15] Train Loss: 0.1542 | Train Acc: 92.99% | Val Loss: 0.2205 | Val Acc: 93.40% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.40%)
# [F4-P2] Epoch [7/15] Train Loss: 0.1264 | Train Acc: 94.83% | Val Loss: 0.1742 | Val Acc: 94.39% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.39%)
# [F4-P2] Epoch [8/15] Train Loss: 0.1351 | Train Acc: 94.45% | Val Loss: 0.1516 | Val Acc: 94.77% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.77%)
# [F4-P2] Epoch [9/15] Train Loss: 0.1233 | Train Acc: 94.73% | Val Loss: 0.1506 | Val Acc: 95.07% | LR: 0.000100
#   ✓ Saved best model (val_acc=95.07%)
# [F4-P2] Epoch [10/15] Train Loss: 0.1132 | Train Acc: 95.19% | Val Loss: 0.1750 | Val Acc: 93.63% | LR: 0.000100
# [F4-P2] Epoch [11/15] Train Loss: 0.1091 | Train Acc: 95.36% | Val Loss: 0.1767 | Val Acc: 93.93% | LR: 0.000100
# [F4-P2] Epoch [12/15] Train Loss: 0.1073 | Train Acc: 95.53% | Val Loss: 0.1403 | Val Acc: 95.00% | LR: 0.000100
# [F4-P2] Epoch [13/15] Train Loss: 0.0981 | Train Acc: 96.17% | Val Loss: 0.1506 | Val Acc: 94.69% | LR: 0.000100
#   Early stopping triggered at epoch 13.
#
#   Extracting OOF predictions for fold 4...
#   Fold 4 OOF accuracy: 95.07%
#   Fold 4 done. Checkpoint: /content/drive/MyDrive/fold4_resnet50.pth
#
# ───────────────────────────────────────────────────────
#   FOLD 5/5 | Train: 5276 | Val: 1319
# ───────────────────────────────────────────────────────
#
#   Phase 1 — Head only
#   [Frozen]  Trainable: 16,392
# [F5-P1] Epoch [1/10] Train Loss: 1.6469 | Train Acc: 29.83% | Val Loss: 1.6413 | Val Acc: 44.12% | LR: 0.001000
#   ✓ Saved best model (val_acc=44.12%)
# [F5-P1] Epoch [2/10] Train Loss: 1.2635 | Train Acc: 52.50% | Val Loss: 1.4519 | Val Acc: 51.25% | LR: 0.001000
#   ✓ Saved best model (val_acc=51.25%)
# [F5-P1] Epoch [3/10] Train Loss: 1.1388 | Train Acc: 58.13% | Val Loss: 1.2912 | Val Acc: 58.83% | LR: 0.001000
#   ✓ Saved best model (val_acc=58.83%)
# [F5-P1] Epoch [4/10] Train Loss: 1.0496 | Train Acc: 61.18% | Val Loss: 1.2077 | Val Acc: 60.96% | LR: 0.001000
#   ✓ Saved best model (val_acc=60.96%)
# [F5-P1] Epoch [5/10] Train Loss: 0.9802 | Train Acc: 62.70% | Val Loss: 1.1374 | Val Acc: 62.47% | LR: 0.001000
#   ✓ Saved best model (val_acc=62.47%)
# [F5-P1] Epoch [6/10] Train Loss: 0.9360 | Train Acc: 64.27% | Val Loss: 1.0774 | Val Acc: 64.52% | LR: 0.001000
#   ✓ Saved best model (val_acc=64.52%)
# [F5-P1] Epoch [7/10] Train Loss: 0.8998 | Train Acc: 64.95% | Val Loss: 1.0343 | Val Acc: 65.73% | LR: 0.001000
#   ✓ Saved best model (val_acc=65.73%)
# [F5-P1] Epoch [8/10] Train Loss: 0.8784 | Train Acc: 65.66% | Val Loss: 1.0184 | Val Acc: 66.94% | LR: 0.001000
#   ✓ Saved best model (val_acc=66.94%)
# [F5-P1] Epoch [9/10] Train Loss: 0.8319 | Train Acc: 67.34% | Val Loss: 0.9728 | Val Acc: 67.70% | LR: 0.001000
#   ✓ Saved best model (val_acc=67.70%)
# [F5-P1] Epoch [10/10] Train Loss: 0.8344 | Train Acc: 67.76% | Val Loss: 0.9627 | Val Acc: 67.17% | LR: 0.001000
#
#   Phase 2 — Partial unfreeze
#   [Partial] Trainable: 22,079,499
# [F5-P2] Epoch [1/15] Train Loss: 0.4942 | Train Acc: 80.17% | Val Loss: 0.3470 | Val Acc: 87.34% | LR: 0.000100
#   ✓ Saved best model (val_acc=87.34%)
# [F5-P2] Epoch [2/15] Train Loss: 0.2989 | Train Acc: 87.30% | Val Loss: 0.2465 | Val Acc: 90.45% | LR: 0.000100
#   ✓ Saved best model (val_acc=90.45%)
# [F5-P2] Epoch [3/15] Train Loss: 0.2091 | Train Acc: 91.45% | Val Loss: 0.2177 | Val Acc: 92.80% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.80%)
# [F5-P2] Epoch [4/15] Train Loss: 0.1922 | Train Acc: 91.98% | Val Loss: 0.1955 | Val Acc: 93.10% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.10%)
# [F5-P2] Epoch [5/15] Train Loss: 0.1688 | Train Acc: 93.06% | Val Loss: 0.2004 | Val Acc: 93.63% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.63%)
# [F5-P2] Epoch [6/15] Train Loss: 0.1654 | Train Acc: 92.89% | Val Loss: 0.2142 | Val Acc: 92.34% | LR: 0.000100
# [F5-P2] Epoch [7/15] Train Loss: 0.1288 | Train Acc: 94.62% | Val Loss: 0.1670 | Val Acc: 93.93% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.93%)
# [F5-P2] Epoch [8/15] Train Loss: 0.1275 | Train Acc: 94.69% | Val Loss: 0.1567 | Val Acc: 94.62% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.62%)
# [F5-P2] Epoch [9/15] Train Loss: 0.1164 | Train Acc: 95.45% | Val Loss: 0.2181 | Val Acc: 93.25% | LR: 0.000100
# [F5-P2] Epoch [10/15] Train Loss: 0.1129 | Train Acc: 94.88% | Val Loss: 0.1781 | Val Acc: 94.54% | LR: 0.000100
# [F5-P2] Epoch [11/15] Train Loss: 0.1052 | Train Acc: 95.66% | Val Loss: 0.1757 | Val Acc: 94.31% | LR: 0.000100
# [F5-P2] Epoch [12/15] Train Loss: 0.0979 | Train Acc: 96.04% | Val Loss: 0.1545 | Val Acc: 95.45% | LR: 0.000100
#   ✓ Saved best model (val_acc=95.45%)
# [F5-P2] Epoch [13/15] Train Loss: 0.0985 | Train Acc: 95.91% | Val Loss: 0.1653 | Val Acc: 94.47% | LR: 0.000100
# [F5-P2] Epoch [14/15] Train Loss: 0.0903 | Train Acc: 96.25% | Val Loss: 0.1492 | Val Acc: 94.77% | LR: 0.000100
# [F5-P2] Epoch [15/15] Train Loss: 0.0802 | Train Acc: 96.85% | Val Loss: 0.1514 | Val Acc: 95.38% | LR: 0.000100
#
#   Extracting OOF predictions for fold 5...
#   Fold 5 OOF accuracy: 95.45%
#   Fold 5 done. Checkpoint: /content/drive/MyDrive/fold5_resnet50.pth
#
# =======================================================
# Overall OOF Accuracy (5-fold): 95.36%
# =======================================================
# OOF arrays saved to Drive.

# %%
try:
    # Check if overall_oof already exists in memory
    overall_oof
    print(f"overall_oof already in memory: {overall_oof:.2f}%")
except NameError:
    # Variable lost — recover from saved .npy files
    oof_p = np.load(f"/content/drive/MyDrive/oof_{model_name}_probs.npy")
    oof_l = np.load(f"/content/drive/MyDrive/oof_{model_name}_labels.npy")
    overall_oof = (oof_p.argmax(1) == oof_l).mean() * 100
    print(f"Recovered overall_oof: {overall_oof:.2f}%")
# Out:
# Recovered overall_oof: 95.36%

# %%
# ─────────────────────────────────────────────
# 13. Final Model (full train set)
# ─────────────────────────────────────────────
"""
After OOF is done, train one final model on the FULL train set.
This is the model used in Notebook 2 (ensemble) and Notebook 3 (stacking).
It has seen all training data so it will be stronger than any fold model.
"""
print(f"\n{'='*55}")
print(f"  FINAL MODEL — Full train set")
print(f"{'='*55}")

# Full train loader with weighted sampler
full_sample_w = [weights[label]
                 for _, label in full_train_aug.samples]
full_sampler  = WeightedRandomSampler(
    full_sample_w, len(full_sample_w), replacement=True
)
full_train_loader = DataLoader(full_train_aug, batch_size=32,
                               sampler=full_sampler, num_workers=2)

if model_name == "mobilenetv2":
    final_model = build_mobilenetv2(num_classes, pretrained=True)
else:
    final_model = build_resnet50(num_classes, pretrained=True)

final_save = f"/content/drive/MyDrive/fine_tuned_best_{model_name}_eca.pth"

# Phase 1
print("\nFinal — Phase 1 (head only)")
freeze_backbone(final_model, model_name)
final_model, h1, _ = train_one_phase(
    final_model, full_train_loader, val_loader,
    num_epochs=10, lr=1e-3,
    save_path=final_save,
    phase_label="Final-P1",
    patience=4
)

# Phase 2
print("\nFinal — Phase 2 (partial unfreeze)")
unfreeze_partial(final_model, model_name)
final_model, h2, best_val_acc = train_one_phase(
    final_model, full_train_loader, val_loader,
    num_epochs=20, lr=1e-4,
    save_path=final_save,
    phase_label="Final-P2",
    patience=6
)

# Load best final weights
final_model.load_state_dict(
    torch.load(final_save, map_location=device, weights_only=True)
)
# Out:
# =======================================================
#   FINAL MODEL — Full train set
# =======================================================
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 210MB/s]
# Final — Phase 1 (head only)
#   [Frozen]  Trainable: 16,392
# [Final-P1] Epoch [1/10] Train Loss: 1.5186 | Train Acc: 38.83% | Val Loss: 1.4605 | Val Acc: 51.41% | LR: 0.001000
#   ✓ Saved best model (val_acc=51.41%)
# [Final-P1] Epoch [2/10] Train Loss: 1.1166 | Train Acc: 59.21% | Val Loss: 1.2376 | Val Acc: 59.48% | LR: 0.001000
#   ✓ Saved best model (val_acc=59.48%)
# [Final-P1] Epoch [3/10] Train Loss: 0.9806 | Train Acc: 63.03% | Val Loss: 1.0958 | Val Acc: 64.50% | LR: 0.001000
#   ✓ Saved best model (val_acc=64.50%)
# [Final-P1] Epoch [4/10] Train Loss: 0.9356 | Train Acc: 64.75% | Val Loss: 1.0328 | Val Acc: 67.47% | LR: 0.001000
#   ✓ Saved best model (val_acc=67.47%)
# [Final-P1] Epoch [5/10] Train Loss: 0.8678 | Train Acc: 66.35% | Val Loss: 0.9855 | Val Acc: 68.67% | LR: 0.001000
#   ✓ Saved best model (val_acc=68.67%)
# [Final-P1] Epoch [6/10] Train Loss: 0.8377 | Train Acc: 68.57% | Val Loss: 0.8972 | Val Acc: 69.45% | LR: 0.001000
#   ✓ Saved best model (val_acc=69.45%)
# [Final-P1] Epoch [7/10] Train Loss: 0.8158 | Train Acc: 68.52% | Val Loss: 0.8703 | Val Acc: 68.81% | LR: 0.001000
# [Final-P1] Epoch [8/10] Train Loss: 0.7920 | Train Acc: 68.90% | Val Loss: 0.8410 | Val Acc: 72.14% | LR: 0.001000
#   ✓ Saved best model (val_acc=72.14%)
# [Final-P1] Epoch [9/10] Train Loss: 0.7773 | Train Acc: 68.79% | Val Loss: 0.8036 | Val Acc: 72.14% | LR: 0.001000
# [Final-P1] Epoch [10/10] Train Loss: 0.7733 | Train Acc: 68.92% | Val Loss: 0.8022 | Val Acc: 74.33% | LR: 0.001000
#   ✓ Saved best model (val_acc=74.33%)
#
# Final — Phase 2 (partial unfreeze)
#   [Partial] Trainable: 22,079,499
# [Final-P2] Epoch [1/20] Train Loss: 0.4523 | Train Acc: 81.67% | Val Loss: 0.3457 | Val Acc: 87.84% | LR: 0.000100
#   ✓ Saved best model (val_acc=87.84%)
# [Final-P2] Epoch [2/20] Train Loss: 0.2656 | Train Acc: 88.70% | Val Loss: 0.2451 | Val Acc: 91.65% | LR: 0.000100
#   ✓ Saved best model (val_acc=91.65%)
# [Final-P2] Epoch [3/20] Train Loss: 0.2176 | Train Acc: 90.66% | Val Loss: 0.2348 | Val Acc: 91.87% | LR: 0.000100
#   ✓ Saved best model (val_acc=91.87%)
# [Final-P2] Epoch [4/20] Train Loss: 0.1859 | Train Acc: 92.16% | Val Loss: 0.2042 | Val Acc: 92.57% | LR: 0.000100
#   ✓ Saved best model (val_acc=92.57%)
# [Final-P2] Epoch [5/20] Train Loss: 0.1693 | Train Acc: 93.06% | Val Loss: 0.2283 | Val Acc: 92.22% | LR: 0.000100
# [Final-P2] Epoch [6/20] Train Loss: 0.1393 | Train Acc: 93.93% | Val Loss: 0.1982 | Val Acc: 93.14% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.14%)
# [Final-P2] Epoch [7/20] Train Loss: 0.1241 | Train Acc: 94.47% | Val Loss: 0.1905 | Val Acc: 93.71% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.71%)
# [Final-P2] Epoch [8/20] Train Loss: 0.1200 | Train Acc: 94.68% | Val Loss: 0.1733 | Val Acc: 93.92% | LR: 0.000100
#   ✓ Saved best model (val_acc=93.92%)
# [Final-P2] Epoch [9/20] Train Loss: 0.1164 | Train Acc: 94.87% | Val Loss: 0.1788 | Val Acc: 94.20% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.20%)
# [Final-P2] Epoch [10/20] Train Loss: 0.1101 | Train Acc: 95.39% | Val Loss: 0.1650 | Val Acc: 94.84% | LR: 0.000100
#   ✓ Saved best model (val_acc=94.84%)
# [Final-P2] Epoch [11/20] Train Loss: 0.0918 | Train Acc: 96.29% | Val Loss: 0.1295 | Val Acc: 95.76% | LR: 0.000100
#   ✓ Saved best model (val_acc=95.76%)
# [Final-P2] Epoch [12/20] Train Loss: 0.1044 | Train Acc: 95.80% | Val Loss: 0.1420 | Val Acc: 95.47% | LR: 0.000100
# [Final-P2] Epoch [13/20] Train Loss: 0.1021 | Train Acc: 95.86% | Val Loss: 0.1601 | Val Acc: 94.91% | LR: 0.000100
# [Final-P2] Epoch [14/20] Train Loss: 0.0926 | Train Acc: 96.01% | Val Loss: 0.1636 | Val Acc: 94.98% | LR: 0.000100
# [Final-P2] Epoch [15/20] Train Loss: 0.0961 | Train Acc: 95.74% | Val Loss: 0.1230 | Val Acc: 95.62% | LR: 0.000100
# [Final-P2] Epoch [16/20] Train Loss: 0.0723 | Train Acc: 96.91% | Val Loss: 0.1391 | Val Acc: 95.69% | LR: 0.000100
# [Final-P2] Epoch [17/20] Train Loss: 0.0811 | Train Acc: 96.56% | Val Loss: 0.1568 | Val Acc: 95.26% | LR: 0.000100
#   Early stopping triggered at epoch 17.
# <All keys matched successfully>

# %%
# ─────────────────────────────────────────────
# 14. PLOT TRAINING HISTORY
# ─────────────────────────────────────────────
plot_history(h1, h2, model_name=model_name)

# %%
# ─────────────────────────────────────────────
# 15. EVALUATE FINAL MODEL ON TEST SET
# ─────────────────────────────────────────────
print("\n" + "="*60)
print("TEST EVALUATION")
print("="*60)

# test_acc, all_labels, all_preds, all_probs = evaluate_model(
#    model,
#    test_loader,
#    test_loader_tta=test_loader_tta,   # pass None to skip TTA
#    class_names=train_dataset.classes
# )

test_acc, all_labels, all_preds = evaluate_final(
    final_model, test_loader, test_loader_tta,
    full_train_aug.classes , model_name
)
# Out:
# ============================================================
# TEST EVALUATION
# ============================================================
#
# Final Test Accuracy (TTA): 95.48%
#                  precision    recall  f1-score   support
#
# Algal leaf spot       0.96      0.95      0.96       196
#    Brown blight       0.94      0.91      0.93       177
#     Gray blight       0.97      0.93      0.95       242
# Green mirid bug       0.85      0.94      0.89       126
#         Healthy       0.96      1.00      0.98       266
#      Helopeltis       0.97      0.95      0.96       197
#   Red leaf spot       1.00      0.99      0.99       150
#      Red spider       0.97      0.94      0.95        63
#
#        accuracy                           0.95      1417
#       macro avg       0.95      0.95      0.95      1417
#    weighted avg       0.96      0.95      0.95      1417

# %%
# ─────────────────────────────────────────────
# 16. SAVE FINAL CHECKPOINT
# ─────────────────────────────────────────────

torch.save({
    "model_state_dict": final_model.state_dict(),
    "model_name":       model_name,
    "num_classes":      num_classes,
    "class_to_idx":     full_train_aug.class_to_idx,
    "idx_to_class":     {v: k for k, v in
                         full_train_aug.class_to_idx.items()},
    "eca":              True,
    "val_accuracy":     best_val_acc,
    "test_accuracy":    test_acc,
    "oof_accuracy":     overall_oof,
}, f"/content/drive/MyDrive/fine_tuned_{model_name}_eca_checkpoint.pth")

print(f"\n✓ Final checkpoint saved.")
print(f"  OOF  Accuracy : {overall_oof:.2f}%")
print(f"  Val  Accuracy : {best_val_acc:.2f}%")
print(f"  Test Accuracy : {test_acc:.2f}%")
# Out:
# ✓ Final checkpoint saved.
#   OOF  Accuracy : 95.36%
#   Val  Accuracy : 95.76%
#   Test Accuracy : 95.48%
